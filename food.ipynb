# %%
import json
import requests
import pandas as pd

#Clé API
API_KEY = "-rNtfI2lxUWH6YHZBqnAeYQ9rzpcAAn8dT-wshmTRxwON7ytBFNjVq8hbt527dD_G2XnF5BLApATmZmcTP0RwxLxqjc5MnBGfFY0Rb03fJ3Y9LJwvAn4fLIgAY5_Z3Yx"

#URL de base
url = "https://api.yelp.com/v3/businesses/search"

#Paramètres de la requête
params = {
    "location": "France",  # Exemple : ville
    "term": "restaurants",       # Exemple : type d'entreprise
    "limit": 50,                 # Nombre de résultats
    "offset": 0,                 # Pagination
    "sort_by": "best_match",     # Critères de tri
}

#En-têtes HTTP
headers = {
    "Authorization": f"Bearer {API_KEY}",  # Clé API
    "Accept": "application/json"          # Format attendu
}

#Envoi de la requête GET
response = requests.get(url, headers=headers, params=params)

# #Vérification du statut de la requête

data = response.json()  # Extraction des données JSON
data         # Affiche les résultats
# Out:
# {'businesses': [{'id': '-0iLH7iQNYtoURciDpJf6w',
#    'alias': 'le-comptoir-de-la-gastronomie-paris',
#    'name': 'Le Comptoir de la Gastronomie',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/nNraWWnw2MgnEPA6fh53pQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-comptoir-de-la-gastronomie-paris?adjust_creative=NnnrNySybEItfMzq-c4qFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NnnrNySybEItfMzq-c4qFw',
#    'review_count': 1397,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 48.8645157999652,
#     'longitude': 2.34540185646608},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': '34 rue Montmartre',
#     'address2': '',
#     'address3': '',
#     'city': 'Paris',
#     'zip_code': '75001',
#     'country': 'FR',
#     'state': '75',
#     'display_address': ['34 rue Montmartre', '75001 Paris', 'France']},
#    'phone': '+33142333132',
#    'display_phone': '+33 1 42 33 31 32',
#    'distance': 370.8275165771047,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1200',
#        'end': '2300',
#        'day': 0},
#       {'is_overnight': False, 'start': '1200', 'end': '2300', 'day': 1},
#       {'is_overnight': False, 'start': '1200', 'end': '2300', 'day': 2},
#       {'is_overnight': False, 'start': '1200', 'end': '2300', 'day': 3},
#       {'is_overnight': False, 'start': '1200', 'end': '0000', 'day': 4},
#       {'is_overnight': False, 'start': '1200', 'end': '0000', 'day': 5}],
#      'hours_type': 'REGULAR',
#      'is_open_now': True}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': '',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'IU9_wVOGBKjfqTTpAXpKcQ',
#    'alias': 'bistro-des-augustins-paris',
#    'name': 'Bistro des Augustins',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ctHDHMiqeUGs8Zcj71nk7g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bistro-des-augustins-paris?adjust_creative=NnnrNySybEItfMzq-c4qFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NnnrNySybEItfMzq-c4qFw',
#    'review_count': 530,
#    'categories': [{'alias': 'bistros', 'title': 'Bistros'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.4,
#    'coordinates': {'latitude': 48.854754, 'longitude': 2.342119},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': '39 quai des Grands Augustins',
#     'address2': None,
#     'address3': None,
#     'city': 'Paris',
#     'zip_code': '75006',
#     'country': 'FR',
#     'state': '75',
#     'display_address': ['39 quai des Grands Augustins',
#      '75006 Paris',
#      'France']},
#    'phone': '+33143540441',
#    'display_phone': '+33 1 43 54 04 41',
#    'distance': 801.1176096949143,
#    'business_hours': [{'open': [{'is_overnight': True,
#        'start': '1000',
#        'end': '0200',
#        'day': 0},
#       {'is_overnight': True, 'start': '1000', 'end': '0200', 'day': 1},
#       {'is_overnight': True, 'start': '1000', 'end': '0200', 'day': 2},
#       {'is_overnight': True, 'start': '1000', 'end': '0200', 'day': 3},
#       {'is_overnight': True, 'start': '1000', 'end': '0200', 'day': 4},
#       {'is_overnight': True, 'start': '1000', 'end': '0200', 'day': 5},
#       {'is_overnight': True, 'start': '1000', 'end': '0200', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': True}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'BuJnfWI86tTxFUon071EKg',
#    'alias': 'brasserie-bellanger-paris',
#    'name': 'Brasserie Bellanger',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/TO1OgGv8ubk-Zew85QtCmw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brasserie-bellanger-paris?adjust_creative=NnnrNySybEItfMzq-c4qFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NnnrNySybEItfMzq-c4qFw',
#    'review_count': 44,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.8,
#    'coordinates': {'latitude': 48.880937, 'longitude': 2.3499401},
#    'transactions': [],
#    'location': {'address1': '140 rue du Faubourg Poissonnière',
#     'address2': '',
#     'address3': None,
#     'city': 'Paris',
#     'zip_code': '75010',
#     'country': 'FR',
#     'state': '01',
#     'display_address': ['140 rue du Faubourg Poissonnière',
#      '75010 Paris',
#      'France']},
#    'phone': '+33954009965',
#    'display_phone': '+33 9 54 00 99 65',
#    'distance': 2185.8423708491837,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '0900',
#        'end': '0000',
#        'day': 0},
#       {'is_overnight': False, 'start': '0900', 'end': '0000', 'day': 1},
#       {'is_overnight': False, 'start': '0900', 'end': '0000', 'day': 2},
#       {'is_overnight': False, 'start': '0900', 'end': '0000', 'day': 3},
#       {'is_overnight': True, 'start': '0900', 'end': '0030', 'day': 4},
#       {'is_overnight': True, 'start': '0900', 'end': '0030', 'day': 5},
#       {'is_overnight': False, 'start': '0900', 'end': '0000', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': True}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'https://nouvellegardegroupe.com/brasserie-bellanger/menus/',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'wLgAxIB7111BcWLWh7KpFw',
#    'alias': 'la-régalade-paris-3',
#    'name': 'La Régalade',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ZaxoANH0xBpvWlWqXlSl7A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-r%C3%A9galade-paris-3?adjust_creative=NnnrNySybEItfMzq-c4qFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NnnrNySybEItfMzq-c4qFw',
#    'review_count': 110,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 48.8616441182389,
#     'longitude': 2.34201570904084},
#    'transactions': [],
#    'price': '€€€',
#    'location': {'address1': '106 rue Saint-Honoré',
#     'address2': '',
#     'address3': '',
#     'city': 'Paris',
#     'zip_code': '75001',
#     'country': 'FR',
#     'state': '75',
#     'display_address': ['106 rue Saint-Honoré', '75001 Paris', 'France']},
#    'phone': '+33142219240',
#    'display_phone': '+33 1 42 21 92 40',
#    'distance': 36.280480383292954,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1200',
#        'end': '1430',
#        'day': 0},
#       {'is_overnight': False, 'start': '1900', 'end': '2300', 'day': 0},
#       {'is_overnight': False, 'start': '1200', 'end': '1430', 'day': 1},
#       {'is_overnight': False, 'start': '1900', 'end': '2300', 'day': 1},
#       {'is_overnight': False, 'start': '1200', 'end': '1430', 'day': 2},
#       {'is_overnight': False, 'start': '1900', 'end': '2300', 'day': 2},
#       {'is_overnight': False, 'start': '1200', 'end': '1430', 'day': 3},
#       {'is_overnight': False, 'start': '1900', 'end': '2300', 'day': 3},
#       {'is_overnight': False, 'start': '1200', 'end': '1430', 'day': 4},
#       {'is_overnight': False, 'start': '1900', 'end': '2300', 'day': 4},
#       {'is_overnight': False, 'start': '1200', 'end': '1430', 'day': 5},
#       {'is_overnight': False, 'start': '1900', 'end': '2300', 'day': 5},
#       {'is_overnight': False, 'start': '1200', 'end': '1430', 'day': 6},
#       {'is_overnight': False, 'start': '1900', 'end': '2300', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': True}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'https://www.gusteau.io//uploads/57fd0596a0cd8.pdf',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'BPqBRgweCDLInSRww9qmYg',
#    'alias': 'le-corner-saint-germain-paris',
#    'name': 'Le Corner Saint Germain',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/1WgV5b-jwZD8KlC5bgMN0A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-corner-saint-germain-paris?adjust_creative=NnnrNySybEItfMzq-c4qFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NnnrNySybEItfMzq-c4qFw',
#    'review_count': 33,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.6,
#    'coordinates': {'latitude': 48.85126, 'longitude': 2.34432},
#    'transactions': [],
#    'location': {'address1': '92 boulevard Saint-Germain',
#     'address2': '',
#     'address3': None,
#     'city': 'Paris',
#     'zip_code': '75005',
#     'country': 'FR',
#     'state': '01',
#     'display_address': ['92 boulevard Saint-Germain',
#      '75005 Paris',
#      'France']},
#    'phone': '+33143543444',
#    'display_phone': '+33 1 43 54 34 44',
#    'distance': 1197.937860767518,
#    'business_hours': [{'open': [{'is_overnight': True,
#        'start': '0900',
#        'end': '0200',
#        'day': 0},
#       {'is_overnight': True, 'start': '0900', 'end': '0200', 'day': 1},
#       {'is_overnight': True, 'start': '0900', 'end': '0200', 'day': 2},
#       {'is_overnight': True, 'start': '0900', 'end': '0200', 'day': 3},
#       {'is_overnight': True, 'start': '0900', 'end': '0200', 'day': 4},
#       {'is_overnight': True, 'start': '0900', 'end': '0200', 'day': 5},
#       {'is_overnight': True, 'start': '0900', 'end': '0200', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': True}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'cEjF41ZQB8-SST8cd3EsEw',
#    'alias': 'l-avant-comptoir-paris-3',
#    'name': "L'Avant Comptoir",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/V38oU4jfwMlY8Ue3vb-dBQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-avant-comptoir-paris-3?adjust_creative=NnnrNySybEItfMzq-c4qFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NnnrNySybEItfMzq-c4qFw',
#    'review_count': 693,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.4,
#    'coordinates': {'latitude': 48.85202, 'longitude': 2.3388},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': "3 carrefour de l'Odéon",
#     'address2': '',
#     'address3': '',
#     'city': 'Paris',
#     'zip_code': '75006',
#     'country': 'FR',
#     'state': '75',
#     'display_address': ["3 carrefour de l'Odéon", '75006 Paris', 'France']},
#    'phone': '+33142384755',
#    'display_phone': '+33 1 42 38 47 55',
#    'distance': 1128.6487353341165,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1200',
#        'end': '2300',
#        'day': 0},
#       {'is_overnight': False, 'start': '1200', 'end': '2300', 'day': 1},
#       {'is_overnight': False, 'start': '1200', 'end': '2300', 'day': 2},
#       {'is_overnight': False, 'start': '1200', 'end': '2300', 'day': 3},
#       {'is_overnight': False, 'start': '1200', 'end': '2300', 'day': 4},
#       {'is_overnight': False, 'start': '1200', 'end': '2300', 'day': 5},
#       {'is_overnight': False, 'start': '1200', 'end': '2300', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': True}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'n601y41nOORUePsM7KsuaA',
#    'alias': 'gambino-paris-2',
#    'name': 'Gambino',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/WS3FxY9FFhmx68ZQY2jWvg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gambino-paris-2?adjust_creative=NnnrNySybEItfMzq-c4qFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NnnrNySybEItfMzq-c4qFw',
#    'review_count': 263,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 48.86736, 'longitude': 2.33298},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': '6 rue Gomboust',
#     'address2': None,
#     'address3': None,
#     'city': 'Paris',
#     'zip_code': '75001',
#     'country': 'FR',
#     'state': '75',
#     'display_address': ['6 rue Gomboust', '75001 Paris', 'France']},
#    'phone': '+33142601270',
#    'display_phone': '+33 1 42 60 12 70',
#    'distance': 901.5001287226743,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1200',
#        'end': '1500',
#        'day': 0},
#       {'is_overnight': False, 'start': '1900', 'end': '2300', 'day': 0},
#       {'is_overnight': False, 'start': '1200', 'end': '1500', 'day': 1},
#       {'is_overnight': False, 'start': '1900', 'end': '2300', 'day': 1},
#       {'is_overnight': False, 'start': '1200', 'end': '1500', 'day': 2},
#       {'is_overnight': False, 'start': '1900', 'end': '2300', 'day': 2},
#       {'is_overnight': False, 'start': '1200', 'end': '1500', 'day': 3},
#       {'is_overnight': False, 'start': '1900', 'end': '2300', 'day': 3},
#       {'is_overnight': False, 'start': '1200', 'end': '1500', 'day': 4},
#       {'is_overnight': False, 'start': '1900', 'end': '2300', 'day': 4},
#       {'is_overnight': False, 'start': '1200', 'end': '1500', 'day': 5},
#       {'is_overnight': False, 'start': '1900', 'end': '2300', 'day': 5}],
#      'hours_type': 'REGULAR',
#      'is_open_now': True}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'https://www.gambino-restaurant.fr/#menu-321412',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'n-XIbgR-Gwb1CqBMyjwj0w',
#    'alias': 'chez-fernand-paris',
#    'name': 'Chez Fernand',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/bM8eBinKBCStRy5ye5oi8w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chez-fernand-paris?adjust_creative=NnnrNySybEItfMzq-c4qFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NnnrNySybEItfMzq-c4qFw',
#    'review_count': 263,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.4,
#    'coordinates': {'latitude': 48.85461, 'longitude': 2.33954},
#    'transactions': [],
#    'price': '€€€',
#    'location': {'address1': '9 rue Christine',
#     'address2': None,
#     'address3': None,
#     'city': 'Paris',
#     'zip_code': '75006',
#     'country': 'FR',
#     'state': '75',
#     'display_address': ['9 rue Christine', '75006 Paris', 'France']},
#    'phone': '+33143251855',
#    'display_phone': '+33 1 43 25 18 55',
#    'distance': 839.1033071385376,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1230',
#        'end': '1430',
#        'day': 0},
#       {'is_overnight': False, 'start': '1930', 'end': '2300', 'day': 0},
#       {'is_overnight': False, 'start': '1230', 'end': '1430', 'day': 1},
#       {'is_overnight': False, 'start': '1930', 'end': '2300', 'day': 1},
#       {'is_overnight': False, 'start': '1230', 'end': '1430', 'day': 2},
#       {'is_overnight': False, 'start': '1930', 'end': '2300', 'day': 2},
#       {'is_overnight': False, 'start': '1230', 'end': '1430', 'day': 3},
#       {'is_overnight': False, 'start': '1930', 'end': '2300', 'day': 3},
#       {'is_overnight': False, 'start': '1230', 'end': '1430', 'day': 4},
#       {'is_overnight': False, 'start': '1930', 'end': '2300', 'day': 4},
#       {'is_overnight': False, 'start': '1230', 'end': '1430', 'day': 5},
#       {'is_overnight': False, 'start': '1930', 'end': '2300', 'day': 5},
#       {'is_overnight': False, 'start': '1230', 'end': '1430', 'day': 6},
#       {'is_overnight': False, 'start': '1930', 'end': '2300', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': True}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'e6RHSG0d94yzA3McN-eFxg',
#    'alias': 'gemini-paris-2',
#    'name': 'Gemini',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/YULDp2pKvo_AoZSyPPDWLw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gemini-paris-2?adjust_creative=NnnrNySybEItfMzq-c4qFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NnnrNySybEItfMzq-c4qFw',
#    'review_count': 44,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 48.8593674647599,
#     'longitude': 2.34705866389581},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': '16 rue des Halles',
#     'address2': '',
#     'address3': '',
#     'city': 'Paris',
#     'zip_code': '75001',
#     'country': 'FR',
#     'state': '75',
#     'display_address': ['16 rue des Halles', '75001 Paris', 'France']},
#    'phone': '+33142615920',
#    'display_phone': '+33 1 42 61 59 20',
#    'distance': 460.5143411189723,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1200',
#        'end': '1500',
#        'day': 0},
#       {'is_overnight': False, 'start': '1900', 'end': '2300', 'day': 0},
#       {'is_overnight': False, 'start': '1200', 'end': '1500', 'day': 1},
#       {'is_overnight': False, 'start': '1900', 'end': '2300', 'day': 1},
#       {'is_overnight': False, 'start': '1200', 'end': '1500', 'day': 2},
#       {'is_overnight': False, 'start': '1900', 'end': '2300', 'day': 2},
#       {'is_overnight': False, 'start': '1200', 'end': '1500', 'day': 3},
#       {'is_overnight': False, 'start': '1900', 'end': '2300', 'day': 3},
#       {'is_overnight': False, 'start': '1200', 'end': '1500', 'day': 4},
#       {'is_overnight': False, 'start': '1900', 'end': '2300', 'day': 4},
#       {'is_overnight': False, 'start': '1200', 'end': '1500', 'day': 5},
#       {'is_overnight': False, 'start': '1900', 'end': '2300', 'day': 5},
#       {'is_overnight': False, 'start': '1200', 'end': '1500', 'day': 6},
#       {'is_overnight': False, 'start': '1900', 'end': '2300', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': True}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': '28m3vU-aLX76lMEyT3WL5Q',
#    'alias': 'pain-vin-fromages-paris',
#    'name': 'Pain Vin Fromages',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gBaxX3MHScEyCWpLGzG2Ew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pain-vin-fromages-paris?adjust_creative=NnnrNySybEItfMzq-c4qFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NnnrNySybEItfMzq-c4qFw',
#    'review_count': 279,
#    'categories': [{'alias': 'fondue', 'title': 'Fondue'}],
#    'rating': 4.4,
#    'coordinates': {'latitude': 48.860525, 'longitude': 2.354439},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': "3 rue Geoffroy-l'Angevin",
#     'address2': None,
#     'address3': None,
#     'city': 'Paris',
#     'zip_code': '75004',
#     'country': 'FR',
#     'state': '75',
#     'display_address': ["3 rue Geoffroy-l'Angevin", '75004 Paris', 'France']},
#    'phone': '+33142740752',
#    'display_phone': '+33 1 42 74 07 52',
#    'distance': 913.1624141139349,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1900',
#        'end': '2330',
#        'day': 0},
#       {'is_overnight': False, 'start': '1900', 'end': '2330', 'day': 1},
#       {'is_overnight': False, 'start': '1900', 'end': '2330', 'day': 2},
#       {'is_overnight': False, 'start': '1900', 'end': '2330', 'day': 3},
#       {'is_overnight': False, 'start': '1900', 'end': '2330', 'day': 4},
#       {'is_overnight': False, 'start': '1900', 'end': '2330', 'day': 5},
#       {'is_overnight': False, 'start': '1900', 'end': '2330', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': True}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://painvinfromages.com/menu-fr/',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'aveslz7waP99LSjW_MnLBw',
#    'alias': 'le-café-paris-5',
#    'name': 'Le Café',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/eaz4V7aN3IlW8Fi6zovs5w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-caf%C3%A9-paris-5?adjust_creative=NnnrNySybEItfMzq-c4qFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NnnrNySybEItfMzq-c4qFw',
#    'review_count': 68,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 48.86483, 'longitude': 2.34588},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': '62 rue Tiquetonne',
#     'address2': '',
#     'address3': '',
#     'city': 'Paris',
#     'zip_code': '75002',
#     'country': 'FR',
#     'state': '75',
#     'display_address': ['62 rue Tiquetonne', '75002 Paris', 'France']},
#    'phone': '+33140390800',
#    'display_phone': '+33 1 40 39 08 00',
#    'distance': 429.81339089351815,
#    'business_hours': [{'open': [{'is_overnight': True,
#        'start': '0800',
#        'end': '0200',
#        'day': 0},
#       {'is_overnight': True, 'start': '0800', 'end': '0200', 'day': 1},
#       {'is_overnight': True, 'start': '0800', 'end': '0200', 'day': 2},
#       {'is_overnight': True, 'start': '0800', 'end': '0200', 'day': 3},
#       {'is_overnight': True, 'start': '0800', 'end': '0200', 'day': 4},
#       {'is_overnight': True, 'start': '0800', 'end': '0200', 'day': 5},
#       {'is_overnight': True, 'start': '0900', 'end': '0200', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': True}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'SkZWjUwmNgcCJJQvgJT1DQ',
#    'alias': 'la-jacobine-paris',
#    'name': 'La Jacobine',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/z58ZZ6J9ZIs7IWn1_y2WKQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-jacobine-paris?adjust_creative=NnnrNySybEItfMzq-c4qFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NnnrNySybEItfMzq-c4qFw',
#    'review_count': 392,
#    'categories': [{'alias': 'tea', 'title': 'Tea Rooms'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 48.8532345157095,
#     'longitude': 2.33900494873524},
#    'transactions': [],
#    'price': '€€€',
#    'location': {'address1': '59-61 rue Saint-André des Arts',
#     'address2': '',
#     'address3': '',
#     'city': 'Paris',
#     'zip_code': '75006',
#     'country': 'FR',
#     'state': '75',
#     'display_address': ['59-61 rue Saint-André des Arts',
#      '75006 Paris',
#      'France']},
#    'phone': '+33146341595',
#    'display_phone': '+33 1 46 34 15 95',
#    'distance': 996.9503876116776,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1800',
#        'end': '2330',
#        'day': 0},
#       {'is_overnight': False, 'start': '1200', 'end': '2330', 'day': 1},
#       {'is_overnight': False, 'start': '1200', 'end': '2330', 'day': 2},
#       {'is_overnight': False, 'start': '1200', 'end': '2330', 'day': 3},
#       {'is_overnight': False, 'start': '1200', 'end': '2330', 'day': 4},
#       {'is_overnight': False, 'start': '1200', 'end': '2330', 'day': 5},
#       {'is_overnight': False, 'start': '1200', 'end': '2330', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': True}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'DwZsEW-rBrBBLHioGdKoAg',
#    'alias': 'la-fontaine-de-mars-paris-2',
#    'name': 'La Fontaine de Mars',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/uI4ifexZBDt-tW1Im7B_8w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-fontaine-de-mars-paris-2?adjust_creative=NnnrNySybEItfMzq-c4qFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NnnrNySybEItfMzq-c4qFw',
#    'review_count': 368,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.4,
#    'coordinates': {'latitude': 48.858394, 'longitude': 2.302568},
#    'transactions': [],
#    'price': '€€€',
#    'location': {'address1': '129 rue Saint-Dominique',
#     'address2': None,
#     'address3': None,
#     'city': 'Paris',
#     'zip_code': '75007',
#     'country': 'FR',
#     'state': '75',
#     'display_address': ['129 rue Saint-Dominique', '75007 Paris', 'France']},
#    'phone': '+33147054644',
#    'display_phone': '+33 1 47 05 46 44',
#    'distance': 2922.4633600414268,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1200',
#        'end': '2300',
#        'day': 0},
#       {'is_overnight': False, 'start': '1200', 'end': '2300', 'day': 1},
#       {'is_overnight': False, 'start': '1200', 'end': '2300', 'day': 2},
#       {'is_overnight': False, 'start': '1200', 'end': '2300', 'day': 3},
#       {'is_overnight': False, 'start': '1200', 'end': '2300', 'day': 4},
#       {'is_overnight': False, 'start': '1200', 'end': '2300', 'day': 5},
#       {'is_overnight': False, 'start': '1200', 'end': '2300', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': True}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://www.fontainedemars.com/nos-menus-et-boissons/',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': '15tUXLav_KIRjszu8IJJ3w',
#    'alias': 'le-bistrot-des-vosges-paris',
#    'name': 'Le Bistrot des Vosges',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-IQcQMCy58EY6wMN3iiPZg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-bistrot-des-vosges-paris?adjust_creative=NnnrNySybEItfMzq-c4qFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NnnrNySybEItfMzq-c4qFw',
#    'review_count': 92,
#    'categories': [{'alias': 'bistros', 'title': 'Bistros'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 48.8557424, 'longitude': 2.368231},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': '31 bd Beaumarchais',
#     'address2': '',
#     'address3': '',
#     'city': 'Paris',
#     'zip_code': '75004',
#     'country': 'FR',
#     'state': '75',
#     'display_address': ['31 bd Beaumarchais', '75004 Paris', 'France']},
#    'phone': '+33142729485',
#    'display_phone': '+33 1 42 72 94 85',
#    'distance': 2029.4970632725788,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '0900',
#        'end': '2230',
#        'day': 0},
#       {'is_overnight': False, 'start': '0900', 'end': '2230', 'day': 1},
#       {'is_overnight': False, 'start': '0900', 'end': '2230', 'day': 2},
#       {'is_overnight': False, 'start': '0900', 'end': '2230', 'day': 3},
#       {'is_overnight': False, 'start': '0900', 'end': '2230', 'day': 4},
#       {'is_overnight': False, 'start': '0900', 'end': '2230', 'day': 5},
#       {'is_overnight': False, 'start': '0900', 'end': '2230', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': True}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'OlJM2JixZiOdr_XwZ-zfNQ',
#    'alias': 'marcelle-paris-3',
#    'name': 'Marcelle',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7HOF_S04xdNGAAiEi5Fuew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/marcelle-paris-3?adjust_creative=NnnrNySybEItfMzq-c4qFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NnnrNySybEItfMzq-c4qFw',
#    'review_count': 3,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 48.864111, 'longitude': 2.345627},
#    'transactions': [],
#    'location': {'address1': '9 rue Antoine Vollon',
#     'address2': '',
#     'address3': None,
#     'city': 'Paris',
#     'zip_code': '75012',
#     'country': 'FR',
#     'state': '75',
#     'display_address': ['9 rue Antoine Vollon', '75012 Paris', 'France']},
#    'phone': '+33983248218',
#    'display_phone': '+33 9 83 24 82 18',
#    'distance': 349.36165037709986,
#    'business_hours': [{'open': [{'is_overnight': True,
#        'start': '1100',
#        'end': '0100',
#        'day': 1},
#       {'is_overnight': True, 'start': '1100', 'end': '0100', 'day': 2},
#       {'is_overnight': True, 'start': '1100', 'end': '0100', 'day': 3},
#       {'is_overnight': True, 'start': '1100', 'end': '0100', 'day': 4},
#       {'is_overnight': True, 'start': '1100', 'end': '0200', 'day': 5},
#       {'is_overnight': False, 'start': '1100', 'end': '1700', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': True}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://restaurantmarcelle.com/carte/',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'WHHt_Jb8Tgidn9mW7oDnIg',
#    'alias': 'la-coïncidence-paris-4',
#    'name': 'La Coïncidence',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/b0oaxZUFu4RpZ7cCW6j2XA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-co%C3%AFncidence-paris-4?adjust_creative=NnnrNySybEItfMzq-c4qFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NnnrNySybEItfMzq-c4qFw',
#    'review_count': 517,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 48.868105, 'longitude': 2.284365},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': '15 rue Mesnil',
#     'address2': '',
#     'address3': '',
#     'city': 'Paris',
#     'zip_code': '75116',
#     'country': 'FR',
#     'state': '75',
#     'display_address': ['15 rue Mesnil', '75116 Paris', 'France']},
#    'phone': '+33147559644',
#    'display_phone': '+33 1 47 55 96 44',
#    'distance': 4281.588159098756,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1900',
#        'end': '2300',
#        'day': 0},
#       {'is_overnight': False, 'start': '1200', 'end': '1430', 'day': 1},
#       {'is_overnight': False, 'start': '1900', 'end': '2230', 'day': 1},
#       {'is_overnight': False, 'start': '1200', 'end': '1430', 'day': 2},
#       {'is_overnight': False, 'start': '1900', 'end': '2230', 'day': 2},
#       {'is_overnight': False, 'start': '1200', 'end': '1430', 'day': 3},
#       {'is_overnight': False, 'start': '1900', 'end': '2230', 'day': 3},
#       {'is_overnight': False, 'start': '1200', 'end': '1430', 'day': 4},
#       {'is_overnight': False, 'start': '1900', 'end': '2230', 'day': 4},
#       {'is_overnight': False, 'start': '1900', 'end': '2300', 'day': 5}],
#      'hours_type': 'REGULAR',
#      'is_open_now': True}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://www.lacoincidence.com/menus-carte/',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'sFdV05m6Pw5Rw6DdrpQlIw',
#    'alias': 'l-escargot-paris-3',
#    'name': "L'Escargot",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/mvTnZRX0Jn7R2pXsKYtjvA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-escargot-paris-3?adjust_creative=NnnrNySybEItfMzq-c4qFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NnnrNySybEItfMzq-c4qFw',
#    'review_count': 319,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 3.9,
#    'coordinates': {'latitude': 48.864206, 'longitude': 2.3467},
#    'transactions': [],
#    'price': '€€€',
#    'location': {'address1': '38 rue Montorgueil',
#     'address2': None,
#     'address3': None,
#     'city': 'Paris',
#     'zip_code': '75001',
#     'country': 'FR',
#     'state': '75',
#     'display_address': ['38 rue Montorgueil', '75001 Paris', 'France']},
#    'phone': '+33142368351',
#    'display_phone': '+33 1 42 36 83 51',
#    'distance': 416.3347408028919,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1200',
#        'end': '2300',
#        'day': 0},
#       {'is_overnight': False, 'start': '1200', 'end': '2300', 'day': 1},
#       {'is_overnight': False, 'start': '1200', 'end': '2300', 'day': 2},
#       {'is_overnight': False, 'start': '1200', 'end': '2300', 'day': 3},
#       {'is_overnight': False, 'start': '1200', 'end': '2300', 'day': 4},
#       {'is_overnight': False, 'start': '1200', 'end': '2300', 'day': 5},
#       {'is_overnight': False, 'start': '1200', 'end': '2300', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': True}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'LwRrembo4omcYIColDl12A',
#    'alias': 'enza-et-famiglia-trattoria-pasta-paris',
#    'name': 'Enza & Famiglia Trattoria Pasta',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/m0Zu5mDQQecXSXw4b-Gj8A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/enza-et-famiglia-trattoria-pasta-paris?adjust_creative=NnnrNySybEItfMzq-c4qFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NnnrNySybEItfMzq-c4qFw',
#    'review_count': 61,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 48.8609426, 'longitude': 2.3433822},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': '89 rue Saint-Honoré',
#     'address2': '',
#     'address3': '',
#     'city': 'Paris',
#     'zip_code': '75001',
#     'country': 'FR',
#     'state': '75',
#     'display_address': ['89 rue Saint-Honoré', '75001 Paris', 'France']},
#    'phone': '+33140410625',
#    'display_phone': '+33 1 40 41 06 25',
#    'distance': 144.62722981220017,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1200',
#        'end': '1430',
#        'day': 0},
#       {'is_overnight': False, 'start': '1930', 'end': '2230', 'day': 0},
#       {'is_overnight': False, 'start': '1200', 'end': '1430', 'day': 1},
#       {'is_overnight': False, 'start': '1930', 'end': '2230', 'day': 1},
#       {'is_overnight': False, 'start': '1200', 'end': '1430', 'day': 2},
#       {'is_overnight': False, 'start': '1930', 'end': '2230', 'day': 2},
#       {'is_overnight': False, 'start': '1200', 'end': '1430', 'day': 3},
#       {'is_overnight': False, 'start': '1930', 'end': '2230', 'day': 3},
#       {'is_overnight': False, 'start': '1200', 'end': '1430', 'day': 4},
#       {'is_overnight': False, 'start': '1930', 'end': '2230', 'day': 4},
#       {'is_overnight': False, 'start': '1200', 'end': '1430', 'day': 5},
#       {'is_overnight': False, 'start': '1930', 'end': '2230', 'day': 5}],
#      'hours_type': 'REGULAR',
#      'is_open_now': True}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'GBfg0200_34Wiu9em7a6jg',
#    'alias': 'chez-georges-paris-6',
#    'name': 'Chez Georges',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/AqCnBw2wZJ2e-fEp576jmQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chez-georges-paris-6?adjust_creative=NnnrNySybEItfMzq-c4qFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NnnrNySybEItfMzq-c4qFw',
#    'review_count': 81,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 3.9,
#    'coordinates': {'latitude': 48.8666718, 'longitude': 2.341457},
#    'transactions': [],
#    'price': '€€€',
#    'location': {'address1': '1 rue du Mail',
#     'address2': None,
#     'address3': None,
#     'city': 'Paris',
#     'zip_code': '75002',
#     'country': 'FR',
#     'state': '75',
#     'display_address': ['1 rue du Mail', '75002 Paris', 'France']},
#    'phone': '+33142600711',
#    'display_phone': '+33 1 42 60 07 11',
#    'distance': 526.5132213769344,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1200',
#        'end': '1430',
#        'day': 0},
#       {'is_overnight': False, 'start': '1900', 'end': '2300', 'day': 0},
#       {'is_overnight': False, 'start': '1200', 'end': '1430', 'day': 1},
#       {'is_overnight': False, 'start': '1900', 'end': '2300', 'day': 1},
#       {'is_overnight': False, 'start': '1200', 'end': '1430', 'day': 2},
#       {'is_overnight': False, 'start': '1900', 'end': '2300', 'day': 2},
#       {'is_overnight': False, 'start': '1200', 'end': '1430', 'day': 3},
#       {'is_overnight': False, 'start': '1900', 'end': '2300', 'day': 3},
#       {'is_overnight': False, 'start': '1200', 'end': '1430', 'day': 4},
#       {'is_overnight': False, 'start': '1900', 'end': '2300', 'day': 4}],
#      'hours_type': 'REGULAR',
#      'is_open_now': True}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'mJMW4j5IYYhbWaBySCPATA',
#    'alias': 'loulou-paris',
#    'name': 'LouLou',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ERFVNRJh2j3AJRF4aLZ0hQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/loulou-paris?adjust_creative=NnnrNySybEItfMzq-c4qFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NnnrNySybEItfMzq-c4qFw',
#    'review_count': 72,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.8,
#    'coordinates': {'latitude': 48.86322, 'longitude': 2.3333},
#    'transactions': [],
#    'price': '€€€',
#    'location': {'address1': '107 rue de Rivoli',
#     'address2': '',
#     'address3': None,
#     'city': 'Paris',
#     'zip_code': '75001',
#     'country': 'FR',
#     'state': '75',
#     'display_address': ['107 rue de Rivoli', '75001 Paris', 'France']},
#    'phone': '+33142604196',
#    'display_phone': '+33 1 42 60 41 96',
#    'distance': 652.622301420393,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1200',
#        'end': '2300',
#        'day': 0},
#       {'is_overnight': False, 'start': '1200', 'end': '2300', 'day': 1},
#       {'is_overnight': False, 'start': '1200', 'end': '2300', 'day': 2},
#       {'is_overnight': False, 'start': '1200', 'end': '2330', 'day': 3},
#       {'is_overnight': False, 'start': '1200', 'end': '2330', 'day': 4}],
#      'hours_type': 'REGULAR',
#      'is_open_now': True}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': '',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': '3drmuEM-hbUqOXVmZRtF4g',
#    'alias': 'freddys-paris',
#    'name': "Freddy's",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/-_oWd1RdPpFpPg6sfggYkw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/freddys-paris?adjust_creative=NnnrNySybEItfMzq-c4qFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NnnrNySybEItfMzq-c4qFw',
#    'review_count': 68,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'french', 'title': 'French'},
#     {'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 4.6,
#    'coordinates': {'latitude': 48.85424, 'longitude': 2.33685},
#    'transactions': [],
#    'price': '€€€',
#    'location': {'address1': '54 rue de Seine',
#     'address2': '',
#     'address3': '',
#     'city': 'Paris',
#     'zip_code': '75006',
#     'country': 'FR',
#     'state': '75',
#     'display_address': ['54 rue de Seine', '75006 Paris', 'France']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 957.1769081357855,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1200',
#        'end': '0000',
#        'day': 0},
#       {'is_overnight': False, 'start': '1200', 'end': '0000', 'day': 1},
#       {'is_overnight': False, 'start': '1200', 'end': '0000', 'day': 2},
#       {'is_overnight': False, 'start': '1200', 'end': '0000', 'day': 3},
#       {'is_overnight': False, 'start': '1200', 'end': '0000', 'day': 4},
#       {'is_overnight': False, 'start': '1200', 'end': '0000', 'day': 5},
#       {'is_overnight': False, 'start': '1200', 'end': '0000', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': True}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'S1Q2QtWcLP8LUsNeQB7ipQ',
#    'alias': 'pierre-sang-paris-5',
#    'name': 'Pierre Sang',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0HaY3dPKSl0Bb0egpq6FkQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pierre-sang-paris-5?adjust_creative=NnnrNySybEItfMzq-c4qFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NnnrNySybEItfMzq-c4qFw',
#    'review_count': 169,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'korean', 'title': 'Korean'}],
#    'rating': 4.4,
#    'coordinates': {'latitude': 48.86461, 'longitude': 2.37233},
#    'transactions': [],
#    'price': '€€€',
#    'location': {'address1': '55 rue Oberkampf',
#     'address2': '',
#     'address3': '',
#     'city': 'Paris',
#     'zip_code': '75011',
#     'country': 'FR',
#     'state': '75',
#     'display_address': ['55 rue Oberkampf', '75011 Paris', 'France']},
#    'phone': '+33148071204',
#    'display_phone': '+33 1 48 07 12 04',
#    'distance': 2227.4350638436017,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1200',
#        'end': '1430',
#        'day': 0},
#       {'is_overnight': False, 'start': '1900', 'end': '2230', 'day': 0},
#       {'is_overnight': False, 'start': '1200', 'end': '1430', 'day': 1},
#       {'is_overnight': False, 'start': '1900', 'end': '2230', 'day': 1},
#       {'is_overnight': False, 'start': '1200', 'end': '1430', 'day': 2},
#       {'is_overnight': False, 'start': '1900', 'end': '2230', 'day': 2},
#       {'is_overnight': False, 'start': '1200', 'end': '1430', 'day': 3},
#       {'is_overnight': False, 'start': '1900', 'end': '2230', 'day': 3},
#       {'is_overnight': False, 'start': '1200', 'end': '1430', 'day': 4},
#       {'is_overnight': False, 'start': '1900', 'end': '2230', 'day': 4},
#       {'is_overnight': False, 'start': '1200', 'end': '1500', 'day': 5},
#       {'is_overnight': False, 'start': '1900', 'end': '2230', 'day': 5},
#       {'is_overnight': False, 'start': '1200', 'end': '1430', 'day': 6},
#       {'is_overnight': False, 'start': '1900', 'end': '2230', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': True}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'UdyUNz28MNot1SfTQjdE7A',
#    'alias': 'les-petites-bouchées-paris',
#    'name': 'Les Petites Bouchées',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/gPRODzeSwSWKMFT7Mj-ejg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/les-petites-bouch%C3%A9es-paris?adjust_creative=NnnrNySybEItfMzq-c4qFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NnnrNySybEItfMzq-c4qFw',
#    'review_count': 76,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 48.855682, 'longitude': 2.360767},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': '4 rue du Roi de Sicile',
#     'address2': '',
#     'address3': '',
#     'city': 'Paris',
#     'zip_code': '75004',
#     'country': 'FR',
#     'state': '75',
#     'display_address': ['4 rue du Roi de Sicile', '75004 Paris', 'France']},
#    'phone': '+33144614996',
#    'display_phone': '+33 1 44 61 49 96',
#    'distance': 1530.5146456903663,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1130',
#        'end': '1430',
#        'day': 1},
#       {'is_overnight': False, 'start': '1830', 'end': '2300', 'day': 1},
#       {'is_overnight': False, 'start': '1130', 'end': '1500', 'day': 2},
#       {'is_overnight': False, 'start': '1830', 'end': '2300', 'day': 2},
#       {'is_overnight': False, 'start': '1130', 'end': '1430', 'day': 3},
#       {'is_overnight': False, 'start': '1830', 'end': '2300', 'day': 3},
#       {'is_overnight': False, 'start': '1130', 'end': '1430', 'day': 4},
#       {'is_overnight': False, 'start': '1830', 'end': '2300', 'day': 4},
#       {'is_overnight': False, 'start': '1130', 'end': '1530', 'day': 5},
#       {'is_overnight': False, 'start': '1830', 'end': '2300', 'day': 5},
#       {'is_overnight': False, 'start': '0630', 'end': '1000', 'day': 6},
#       {'is_overnight': False, 'start': '1130', 'end': '1430', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': True}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://lespetitesbouchees.com/#menu-pdf1',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'KglDmt_BDOEqmBjJ8X2bPQ',
#    'alias': 'le-relais-de-l-entrecôte-paris-3',
#    'name': 'Le Relais de l’Entrecôte',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/2CAVyIV1WhilN-a1mn9mlA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-relais-de-l-entrec%C3%B4te-paris-3?adjust_creative=NnnrNySybEItfMzq-c4qFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NnnrNySybEItfMzq-c4qFw',
#    'review_count': 606,
#    'categories': [{'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 48.86808, 'longitude': 2.30295},
#    'transactions': [],
#    'price': '€€€',
#    'location': {'address1': '15 rue Marbeuf',
#     'address2': None,
#     'address3': None,
#     'city': 'Paris',
#     'zip_code': '75008',
#     'country': 'FR',
#     'state': '75',
#     'display_address': ['15 rue Marbeuf', '75008 Paris', 'France']},
#    'phone': '+33149520717',
#    'display_phone': '+33 1 49 52 07 17',
#    'distance': 2946.9230410857513,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1200',
#        'end': '1430',
#        'day': 0},
#       {'is_overnight': False, 'start': '1900', 'end': '2330', 'day': 0},
#       {'is_overnight': False, 'start': '1200', 'end': '1430', 'day': 1},
#       {'is_overnight': False, 'start': '1900', 'end': '2330', 'day': 1},
#       {'is_overnight': False, 'start': '1200', 'end': '1430', 'day': 2},
#       {'is_overnight': False, 'start': '1900', 'end': '2330', 'day': 2},
#       {'is_overnight': False, 'start': '1200', 'end': '1430', 'day': 3},
#       {'is_overnight': False, 'start': '1900', 'end': '2330', 'day': 3},
#       {'is_overnight': False, 'start': '1200', 'end': '1430', 'day': 4},
#       {'is_overnight': False, 'start': '1900', 'end': '2330', 'day': 4},
#       {'is_overnight': False, 'start': '1200', 'end': '1430', 'day': 5},
#       {'is_overnight': False, 'start': '1900', 'end': '2330', 'day': 5},
#       {'is_overnight': False, 'start': '1200', 'end': '1430', 'day': 6},
#       {'is_overnight': False, 'start': '1900', 'end': '2330', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': True}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://relaisennr.cluster011.ovh.net/wp-content/uploads/2015/01/carte.jpg',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'ijqSzadlZ9SCXvUEpMimcA',
#    'alias': 'angelina-paris',
#    'name': 'Angelina',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/yeAY17z0rsC_Pv27-gF-Yw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/angelina-paris?adjust_creative=NnnrNySybEItfMzq-c4qFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NnnrNySybEItfMzq-c4qFw',
#    'review_count': 1678,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'tea', 'title': 'Tea Rooms'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 48.865092, 'longitude': 2.328464},
#    'transactions': [],
#    'price': '€€€',
#    'location': {'address1': '226 rue de Rivoli',
#     'address2': None,
#     'address3': None,
#     'city': 'Paris',
#     'zip_code': '75001',
#     'country': 'FR',
#     'state': '75',
#     'display_address': ['226 rue de Rivoli', '75001 Paris', 'France']},
#    'phone': '+33142608200',
#    'display_phone': '+33 1 42 60 82 00',
#    'distance': 1059.8775176567408,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '0730',
#        'end': '1900',
#        'day': 0},
#       {'is_overnight': False, 'start': '0730', 'end': '1900', 'day': 1},
#       {'is_overnight': False, 'start': '0730', 'end': '1900', 'day': 2},
#       {'is_overnight': False, 'start': '0730', 'end': '1900', 'day': 3},
#       {'is_overnight': False, 'start': '0730', 'end': '1930', 'day': 4},
#       {'is_overnight': False, 'start': '0830', 'end': '1930', 'day': 5},
#       {'is_overnight': False, 'start': '0830', 'end': '1930', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': False}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://www.angelina-paris.fr/img/cms/ANGE_RIVOLI_CARTE_PE19_02_19_BD_OK.pdf',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'kYb2q4Li8Cw2PY_I9lCJOw',
#    'alias': 'chez-janou-paris',
#    'name': 'Chez Janou',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-impdS4aihU-Hwih3GAmhw/o.jpg',
# ...
#       {'is_overnight': False, 'start': '1830', 'end': '2245', 'day': 4},
#       {'is_overnight': False, 'start': '1830', 'end': '2245', 'day': 5},
#       {'is_overnight': False, 'start': '1230', 'end': '1430', 'day': 6},
#       {'is_overnight': False, 'start': '1830', 'end': '2245', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': True}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': '',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': '3Mg4L7o7Og9aajb7tee2sQ',
#    'alias': 'le-black-dog-paris',
#    'name': 'Le Black Dog',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/pnjvZQOMS25VWcl55mQEIw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-black-dog-paris?adjust_creative=NnnrNySybEItfMzq-c4qFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NnnrNySybEItfMzq-c4qFw',
#    'review_count': 119,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'argentine', 'title': 'Argentine'}],
#    'rating': 4.2,
#    'coordinates': {'latitude': 48.85943, 'longitude': 2.34918},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': '26 rue des Lombards',
#     'address2': '',
#     'address3': '',
#     'city': 'Paris',
#     'zip_code': '75004',
#     'country': 'FR',
#     'state': '75',
#     'display_address': ['26 rue des Lombards', '75004 Paris', 'France']},
#    'phone': '+33142712227',
#    'display_phone': '+33 1 42 71 22 27',
#    'distance': 588.396229794603,
#    'business_hours': [{'open': [{'is_overnight': True,
#        'start': '1200',
#        'end': '0200',
#        'day': 0},
#       {'is_overnight': True, 'start': '1200', 'end': '0200', 'day': 1},
#       {'is_overnight': True, 'start': '1200', 'end': '0200', 'day': 2},
#       {'is_overnight': True, 'start': '1200', 'end': '0200', 'day': 3},
#       {'is_overnight': True, 'start': '1500', 'end': '0500', 'day': 4},
#       {'is_overnight': True, 'start': '1500', 'end': '0500', 'day': 5},
#       {'is_overnight': True, 'start': '1700', 'end': '0200', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': True}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://blackdog-bar.com/666/cartes/restaurant-fr/',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'ePu3Me3SA4lVM-wGzKk0xA',
#    'alias': 'le-bistro-lyonnais-paris',
#    'name': 'Le Bistro Lyonnais',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8yxPIyVPasV-H1LH-j94MA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-bistro-lyonnais-paris?adjust_creative=NnnrNySybEItfMzq-c4qFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NnnrNySybEItfMzq-c4qFw',
#    'review_count': 32,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.4,
#    'coordinates': {'latitude': 48.84698, 'longitude': 2.37383},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': '6 rue Michel Chasles',
#     'address2': '',
#     'address3': '',
#     'city': 'Paris',
#     'zip_code': '75012',
#     'country': 'FR',
#     'state': '75',
#     'display_address': ['6 rue Michel Chasles', '75012 Paris', 'France']},
#    'phone': '+33155780642',
#    'display_phone': '+33 1 55 78 06 42',
#    'distance': 2854.2995570310463,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '0900',
#        'end': '2300',
#        'day': 0},
#       {'is_overnight': False, 'start': '0900', 'end': '2300', 'day': 1},
#       {'is_overnight': False, 'start': '0900', 'end': '2300', 'day': 2},
#       {'is_overnight': False, 'start': '0900', 'end': '2300', 'day': 3},
#       {'is_overnight': False, 'start': '0900', 'end': '2300', 'day': 4},
#       {'is_overnight': False, 'start': '0900', 'end': '2300', 'day': 5},
#       {'is_overnight': False, 'start': '0900', 'end': '2300', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': True}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://www.lebistrodelyon.com/lacarte.php',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'g9Czar9Jr5s6V_hW6YfErQ',
#    'alias': 'le-bistrot-de-paris-paris-3',
#    'name': 'Le Bistrot de Paris',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/WvoB-lsAqjhTztxyZMz-ig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-bistrot-de-paris-paris-3?adjust_creative=NnnrNySybEItfMzq-c4qFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NnnrNySybEItfMzq-c4qFw',
#    'review_count': 46,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'bistros', 'title': 'Bistros'},
#     {'alias': 'brasseries', 'title': 'Brasseries'}],
#    'rating': 4.4,
#    'coordinates': {'latitude': 48.85854, 'longitude': 2.32946},
#    'transactions': [],
#    'price': '€€€',
#    'location': {'address1': '33 rue de Lille',
#     'address2': None,
#     'address3': None,
#     'city': 'Paris',
#     'zip_code': '75007',
#     'country': 'FR',
#     'state': '75',
#     'display_address': ['33 rue de Lille', '75007 Paris', 'France']},
#    'phone': '+33142611683',
#    'display_phone': '+33 1 42 61 16 83',
#    'distance': 997.2832429994887,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1200',
#        'end': '1430',
#        'day': 1},
#       {'is_overnight': False, 'start': '1900', 'end': '2300', 'day': 1},
#       {'is_overnight': False, 'start': '1200', 'end': '1430', 'day': 2},
#       {'is_overnight': False, 'start': '1900', 'end': '2300', 'day': 2},
#       {'is_overnight': False, 'start': '1200', 'end': '1430', 'day': 3},
#       {'is_overnight': False, 'start': '1900', 'end': '2300', 'day': 3},
#       {'is_overnight': False, 'start': '1200', 'end': '1430', 'day': 4},
#       {'is_overnight': False, 'start': '1900', 'end': '2300', 'day': 4},
#       {'is_overnight': False, 'start': '1200', 'end': '1430', 'day': 5},
#       {'is_overnight': False, 'start': '1900', 'end': '2300', 'day': 5}],
#      'hours_type': 'REGULAR',
#      'is_open_now': True}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'MfmIKDTvTNfpdID38qWVag',
#    'alias': 'le-porte-pot-paris',
#    'name': 'Le Porte Pot',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/cVdotiu1KaHEdZEzsIB_JQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-porte-pot-paris?adjust_creative=NnnrNySybEItfMzq-c4qFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NnnrNySybEItfMzq-c4qFw',
#    'review_count': 138,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'bistros', 'title': 'Bistros'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 48.85134, 'longitude': 2.34452},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': '14 rue Boutebrie',
#     'address2': '',
#     'address3': '',
#     'city': 'Paris',
#     'zip_code': '75005',
#     'country': 'FR',
#     'state': '75',
#     'display_address': ['14 rue Boutebrie', '75005 Paris', 'France']},
#    'phone': '+33143252424',
#    'display_phone': '+33 1 43 25 24 24',
#    'distance': 1186.625618021402,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1830',
#        'end': '0000',
#        'day': 1},
#       {'is_overnight': False, 'start': '1830', 'end': '0000', 'day': 2},
#       {'is_overnight': False, 'start': '1830', 'end': '0000', 'day': 3},
#       {'is_overnight': False, 'start': '1830', 'end': '0000', 'day': 4},
#       {'is_overnight': False, 'start': '1200', 'end': '1400', 'day': 5},
#       {'is_overnight': False, 'start': '1830', 'end': '0000', 'day': 5}],
#      'hours_type': 'REGULAR',
#      'is_open_now': True}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'dlFBHdXr7-_6vfB0C-EHvw',
#    'alias': 'la-maison-de-la-truffe-paris',
#    'name': 'La Maison de la Truffe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Ai4ZCU83adPiFl3KKu0ewA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-maison-de-la-truffe-paris?adjust_creative=NnnrNySybEItfMzq-c4qFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NnnrNySybEItfMzq-c4qFw',
#    'review_count': 109,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 48.87074, 'longitude': 2.3239899},
#    'transactions': [],
#    'price': '€€€€',
#    'location': {'address1': '19 place de la Madeleine',
#     'address2': None,
#     'address3': None,
#     'city': 'Paris',
#     'zip_code': '75008',
#     'country': 'FR',
#     'state': '75',
#     'display_address': ['19 place de la Madeleine', '75008 Paris', 'France']},
#    'phone': '+33142655322',
#    'display_phone': '+33 1 42 65 53 22',
#    'distance': 1652.1561283719873,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1200',
#        'end': '2230',
#        'day': 0},
#       {'is_overnight': False, 'start': '1200', 'end': '2230', 'day': 1},
#       {'is_overnight': False, 'start': '1200', 'end': '2230', 'day': 2},
#       {'is_overnight': False, 'start': '1200', 'end': '2230', 'day': 3},
#       {'is_overnight': False, 'start': '1200', 'end': '2230', 'day': 4},
#       {'is_overnight': False, 'start': '1900', 'end': '2230', 'day': 5}],
#      'hours_type': 'REGULAR',
#      'is_open_now': True}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': '',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': '_qACPRqSQ6Nvd20H8EY3uw',
#    'alias': 'frenchie-paris-4',
#    'name': 'Frenchie',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Ls5o7lKDmRMciQzsp4zJ6A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/frenchie-paris-4?adjust_creative=NnnrNySybEItfMzq-c4qFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NnnrNySybEItfMzq-c4qFw',
#    'review_count': 260,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'rating': 4.4,
#    'coordinates': {'latitude': 48.867754322367, 'longitude': 2.3477420774331},
#    'transactions': [],
#    'price': '€€€€',
#    'location': {'address1': '5 rue du Nil',
#     'address2': None,
#     'address3': None,
#     'city': 'Paris',
#     'zip_code': '75002',
#     'country': 'FR',
#     'state': '75',
#     'display_address': ['5 rue du Nil', '75002 Paris', 'France']},
#    'phone': '+33140399619',
#    'display_phone': '+33 1 40 39 96 19',
#    'distance': 763.3950800840072,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1830',
#        'end': '2300',
#        'day': 0},
#       {'is_overnight': False, 'start': '1830', 'end': '2300', 'day': 1},
#       {'is_overnight': False, 'start': '1830', 'end': '2300', 'day': 2},
#       {'is_overnight': False, 'start': '1830', 'end': '2300', 'day': 3},
#       {'is_overnight': False, 'start': '1830', 'end': '2300', 'day': 4}],
#      'hours_type': 'REGULAR',
#      'is_open_now': True}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://www.frenchie-restaurant.com/menu_restau_fr',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'JDHBFWwmVevqKcSdNWICIw',
#    'alias': 'big-mamma-paris-2',
#    'name': 'Big Mamma',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/R5HBYwStRI7RMbB5AkWKpA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/big-mamma-paris-2?adjust_creative=NnnrNySybEItfMzq-c4qFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NnnrNySybEItfMzq-c4qFw',
#    'review_count': 4,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 48.86813, 'longitude': 2.34329},
#    'transactions': [],
#    'price': '€',
#    'location': {'address1': '111 Rue Réaumur',
#     'address2': '',
#     'address3': None,
#     'city': 'Paris',
#     'zip_code': '75002',
#     'country': 'FR',
#     'state': '75',
#     'display_address': ['111 Rue Réaumur', '75002 Paris', 'France']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 690.4486554394447,
#    'business_hours': [],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'CQi4W2vY8KSiG6n24eaScA',
#    'alias': 'mystery-cuisine-paris',
#    'name': 'Mystery Cuisine',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1JJ9w3OY6GAPL4n7b1CP0A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mystery-cuisine-paris?adjust_creative=NnnrNySybEItfMzq-c4qFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NnnrNySybEItfMzq-c4qFw',
#    'review_count': 17,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.9,
#    'coordinates': {'latitude': 48.86572, 'longitude': 2.33728},
#    'transactions': [],
#    'price': '€€€€',
#    'location': {'address1': '37 Bis Rue De Montpensier',
#     'address2': '',
#     'address3': '',
#     'city': 'Paris',
#     'zip_code': '75001',
#     'country': 'FR',
#     'state': '75',
#     'display_address': ['37 Bis Rue De Montpensier', '75001 Paris', 'France']},
#    'phone': '+33140200302',
#    'display_phone': '+33 1 40 20 03 02',
#    'distance': 549.2936265129155,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '2000',
#        'end': '2345',
#        'day': 2},
#       {'is_overnight': False, 'start': '2000', 'end': '2345', 'day': 3},
#       {'is_overnight': False, 'start': '2000', 'end': '2345', 'day': 4},
#       {'is_overnight': False, 'start': '2000', 'end': '2345', 'day': 5}],
#      'hours_type': 'REGULAR',
#      'is_open_now': True}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'https://mysterycuisine.fr/fr/menu/5316966397396385863',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'ZxtU74SJMRoB8ZQXWwNtRQ',
#    'alias': 'le-soufflé-paris-2',
#    'name': 'Le Soufflé',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/5ZLG6wSHaxdRc6u9tYb4RQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/le-souffl%C3%A9-paris-2?adjust_creative=NnnrNySybEItfMzq-c4qFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NnnrNySybEItfMzq-c4qFw',
#    'review_count': 356,
#    'categories': [{'alias': 'french', 'title': 'French'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 48.86645, 'longitude': 2.32647},
#    'transactions': [],
#    'price': '€€€',
#    'location': {'address1': '36 rue du Mont Thabor',
#     'address2': None,
#     'address3': None,
#     'city': 'Paris',
#     'zip_code': '75001',
#     'country': 'FR',
#     'state': '75',
#     'display_address': ['36 rue du Mont Thabor', '75001 Paris', 'France']},
#    'phone': '+33142602719',
#    'display_phone': '+33 1 42 60 27 19',
#    'distance': 1247.9695897596946,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1200',
#        'end': '1600',
#        'day': 0},
#       {'is_overnight': False, 'start': '1900', 'end': '2200', 'day': 0},
#       {'is_overnight': False, 'start': '1200', 'end': '1600', 'day': 1},
#       {'is_overnight': False, 'start': '1900', 'end': '2200', 'day': 1},
#       {'is_overnight': False, 'start': '1200', 'end': '1600', 'day': 2},
#       {'is_overnight': False, 'start': '1900', 'end': '2200', 'day': 2},
#       {'is_overnight': False, 'start': '1200', 'end': '1600', 'day': 3},
#       {'is_overnight': False, 'start': '1900', 'end': '2200', 'day': 3},
#       {'is_overnight': False, 'start': '1200', 'end': '1600', 'day': 4},
#       {'is_overnight': False, 'start': '1900', 'end': '2200', 'day': 4},
#       {'is_overnight': False, 'start': '1200', 'end': '1600', 'day': 5},
#       {'is_overnight': False, 'start': '1900', 'end': '2200', 'day': 5}],
#      'hours_type': 'REGULAR',
#      'is_open_now': True}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://www.lesouffle.fr/menu-carte',
#     'open24_hours': None,
#     'waitlist_reservation': None}}],
#  'total': 15000,
#  'region': {'center': {'longitude': 2.3421478271484375,
#    'latitude': 48.86195860677958}}}

# %%
import json
import requests
import pandas as pd

#Clé API
API_KEY = "-rNtfI2lxUWH6YHZBqnAeYQ9rzpcAAn8dT-wshmTRxwON7ytBFNjVq8hbt527dD_G2XnF5BLApATmZmcTP0RwxLxqjc5MnBGfFY0Rb03fJ3Y9LJwvAn4fLIgAY5_Z3Yx"

#URL de base
url = "https://api.yelp.com/v3/businesses/search"

#Paramètres de la requête
params = {
    "location": "France",  # Exemple : ville
    "term": "restaurants",       # Exemple : type d'entreprise
    "limit": 50,                 # Nombre de résultats
    "offset": 0,                 # Pagination
    "sort_by": "best_match",     # Critères de tri
}

#En-têtes HTTP
headers = {
    "Authorization": f"Bearer {API_KEY}",  # Clé API
    "Accept": "application/json"          # Format attendu
}
#Envoi de la requête GET
r = requests.get(url, headers=headers, params=params)

#Vérification du statut de la requête

#data = response.json()  # Extraction des données JSON
       # Affiche les résultats
data = json.loads(r.text)
df = pd.json_normalize(data)
data.keys()
df = pd.json_normalize(r.json(), record_path="businesses")
df.head()
# Out:
#                        id                                alias  \
# 0  -0iLH7iQNYtoURciDpJf6w  le-comptoir-de-la-gastronomie-paris
# 1  IU9_wVOGBKjfqTTpAXpKcQ           bistro-des-augustins-paris
# 2  TWsuxL7J0iACK5KplxZMtA              le-p-tit-bistro-paris-2
# 3  BuJnfWI86tTxFUon071EKg            brasserie-bellanger-paris
# 4  BPqBRgweCDLInSRww9qmYg        le-corner-saint-germain-paris
#
#                             name  \
# 0  Le Comptoir de la Gastronomie
# 1           Bistro des Augustins
# 2                Le P'tit Bistro
# 3            Brasserie Bellanger
# 4        Le Corner Saint Germain
#
#                                            image_url  is_closed  \
# 0  https://s3-media4.fl.yelpcdn.com/bphoto/nNraWW...      False
# 1  https://s3-media2.fl.yelpcdn.com/bphoto/ctHDHM...      False
# 2  https://s3-media4.fl.yelpcdn.com/bphoto/lrnzcs...      False
# 3  https://s3-media3.fl.yelpcdn.com/bphoto/TO1OgG...      False
# 4  https://s3-media4.fl.yelpcdn.com/bphoto/1WgV5b...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/le-comptoir-de-la-gas...          1397
# 1  https://www.yelp.com/biz/bistro-des-augustins-...           530
# 2  https://www.yelp.com/biz/le-p-tit-bistro-paris...            28
# 3  https://www.yelp.com/biz/brasserie-bellanger-p...            44
# 4  https://www.yelp.com/biz/le-corner-saint-germa...            33
#
#                                           categories  rating transactions  \
# 0           [{'alias': 'french', 'title': 'French'}]     4.5           []
# 1  [{'alias': 'bistros', 'title': 'Bistros'}, {'a...     4.4           []
# 2  [{'alias': 'brasseries', 'title': 'Brasseries'...     4.7           []
# 3           [{'alias': 'french', 'title': 'French'}]     4.8           []
# 4           [{'alias': 'french', 'title': 'French'}]     4.6           []
#
#    ... location.address3 location.city location.zip_code  location.country  \
# 0  ...                           Paris             75001                FR
# 1  ...              None         Paris             75006                FR
# 2  ...              None         Paris             75004                FR
# 3  ...              None         Paris             75010                FR
# 4  ...              None         Paris             75005                FR
#
#   location.state                           location.display_address  \
# 0             75           [34 rue Montmartre, 75001 Paris, France]
# 1             75  [39 quai des Grands Augustins, 75006 Paris, Fr...
# 2             75          [8 rue Saint-Martin, 75004 Paris, France]
# 3             01  [140 rue du Faubourg Poissonnière, 75010 Paris...
# 4             01  [92 boulevard Saint-Germain, 75005 Paris, France]
#
#    attributes.business_temp_closed  \
# 0                             None
# 1                             None
# 2                             None
# 3                             None
# 4                             None
#
#                                  attributes.menu_url attributes.open24_hours  \
# 0                                                                       None
# 1                                               None                    None
# 2                                               None                    None
# 3  https://nouvellegardegroupe.com/brasserie-bell...                    None
# 4                                               None                    None
#
#   attributes.waitlist_reservation
# 0                            None
# 1                            None
# 2                            None
# 3                            None
# 4                            None
#
# [5 rows x 29 columns]

# %%
data.keys()
df = pd.json_normalize(r.json(), record_path="businesses")
df.head()
# Out:
#                        id                                alias  \
# 0  -0iLH7iQNYtoURciDpJf6w  le-comptoir-de-la-gastronomie-paris
# 1  IU9_wVOGBKjfqTTpAXpKcQ           bistro-des-augustins-paris
# 2  TWsuxL7J0iACK5KplxZMtA              le-p-tit-bistro-paris-2
# 3  BuJnfWI86tTxFUon071EKg            brasserie-bellanger-paris
# 4  BPqBRgweCDLInSRww9qmYg        le-corner-saint-germain-paris
#
#                             name  \
# 0  Le Comptoir de la Gastronomie
# 1           Bistro des Augustins
# 2                Le P'tit Bistro
# 3            Brasserie Bellanger
# 4        Le Corner Saint Germain
#
#                                            image_url  is_closed  \
# 0  https://s3-media4.fl.yelpcdn.com/bphoto/nNraWW...      False
# 1  https://s3-media2.fl.yelpcdn.com/bphoto/ctHDHM...      False
# 2  https://s3-media4.fl.yelpcdn.com/bphoto/lrnzcs...      False
# 3  https://s3-media3.fl.yelpcdn.com/bphoto/TO1OgG...      False
# 4  https://s3-media4.fl.yelpcdn.com/bphoto/1WgV5b...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/le-comptoir-de-la-gas...          1397
# 1  https://www.yelp.com/biz/bistro-des-augustins-...           530
# 2  https://www.yelp.com/biz/le-p-tit-bistro-paris...            28
# 3  https://www.yelp.com/biz/brasserie-bellanger-p...            44
# 4  https://www.yelp.com/biz/le-corner-saint-germa...            33
#
#                                           categories  rating transactions  \
# 0           [{'alias': 'french', 'title': 'French'}]     4.5           []
# 1  [{'alias': 'bistros', 'title': 'Bistros'}, {'a...     4.4           []
# 2  [{'alias': 'brasseries', 'title': 'Brasseries'...     4.7           []
# 3           [{'alias': 'french', 'title': 'French'}]     4.8           []
# 4           [{'alias': 'french', 'title': 'French'}]     4.6           []
#
#    ... location.address3 location.city location.zip_code  location.country  \
# 0  ...                           Paris             75001                FR
# 1  ...              None         Paris             75006                FR
# 2  ...              None         Paris             75004                FR
# 3  ...              None         Paris             75010                FR
# 4  ...              None         Paris             75005                FR
#
#   location.state                           location.display_address  \
# 0             75           [34 rue Montmartre, 75001 Paris, France]
# 1             75  [39 quai des Grands Augustins, 75006 Paris, Fr...
# 2             75          [8 rue Saint-Martin, 75004 Paris, France]
# 3             01  [140 rue du Faubourg Poissonnière, 75010 Paris...
# 4             01  [92 boulevard Saint-Germain, 75005 Paris, France]
#
#    attributes.business_temp_closed  \
# 0                             None
# 1                             None
# 2                             None
# 3                             None
# 4                             None
#
#                                  attributes.menu_url attributes.open24_hours  \
# 0                                                                       None
# 1                                               None                    None
# 2                                               None                    None
# 3  https://nouvellegardegroupe.com/brasserie-bell...                    None
# 4                                               None                    None
#
#   attributes.waitlist_reservation
# 0                            None
# 1                            None
# 2                            None
# 3                            None
# 4                            None
#
# [5 rows x 29 columns]

# %%
import folium
import requests
import json
import pandas as pd

# Clé API
API_KEY = "-rNtfI2lxUWH6YHZBqnAeYQ9rzpcAAn8dT-wshmTRxwON7ytBFNjVq8hbt527dD_G2XnF5BLApATmZmcTP0RwxLxqjc5MnBGfFY0Rb03fJ3Y9LJwvAn4fLIgAY5_Z3Yx"

# URL de base
url = "https://api.yelp.com/v3/businesses/search"

# Paramètres de la requête
params = {
    "location": "Paris",  # Exemple : ville
    "term": "restaurants",  # Exemple : type d'entreprise
    "limit": 50,            # Nombre de résultats
    "sort_by": "best_match",  # Critères de tri
}

# En-têtes HTTP
headers = {
    "Authorization": f"Bearer {API_KEY}",  # Clé API
    "Accept": "application/json"           # Format attendu
}

# Envoi de la requête GET
r = requests.get(url, headers=headers, params=params)

# Vérification du statut de la requête
if r.status_code == 200:
    data = r.json()
    businesses = data['businesses']  # Récupérer les informations sur les entreprises (restaurants)

    # Créer un DataFrame à partir des données
    restaurants_data = []
    for business in businesses:
        name = business['name']
        latitude = business['coordinates']['latitude']
        longitude = business['coordinates']['longitude']
        address = business['location']['address1'] if 'address1' in business['location'] else "N/A"
        url = business['url']
        restaurants_data.append({'Name': name, 'Latitude': latitude, 'Longitude': longitude, 'Address': address, 'URL':url})

    df_restaurants = pd.DataFrame(restaurants_data)

    # Initialiser la carte centrée sur Paris (vous pouvez ajuster selon votre besoin)
    map_center = [48.8566, 2.3522]  # Coordonnées centrées sur Paris
    m = folium.Map(location=map_center, zoom_start=13)

       
     # Ajouter des marqueurs pour chaque restaurant
    for idx, row in df_restaurants.iterrows():
        popup_content = f"""
        <b>{row['Name']}</b><br>
        {row['Address']}<br>
        <a href="{row['URL']}" target="_blank">Lien vers Yelp</a>
        """
        folium.Marker(
            [row['Latitude'], row['Longitude']],
            popup=folium.Popup(popup_content, max_width=300),
            icon=folium.Icon(icon='cutlery', color='blue')
        ).add_to(m)

    # Sauvegarder la carte sous forme de fichier HTML
    m.save("restaurants_map.html")
    print("Carte sauvegardée sous 'restaurants_map.html'.")
else:
    print("Erreur lors de la récupération des données:", r.status_code)
# Out:
# Carte sauvegardée sous 'restaurants_map.html'.

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6b15645fe5cd772e8680505acc0e757f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6b15645fe5cd772e8680505acc0e757f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6b15645fe5cd772e8680505acc0e757f = L.map(
#                 &quot;map_6b15645fe5cd772e8680505acc0e757f&quot;,
#                 {
#                     center: [48.8566, 2.3522],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4ec3227926e0b98ff90cdb9ba54fd431 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4ec3227926e0b98ff90cdb9ba54fd431.addTo(map_6b15645fe5cd772e8680505acc0e757f);
#
#
#             var marker_fbfe499b7bb606233520a13cf5368638 = L.marker(
#                 [48.8645157999652, 2.34540185646608],
#                 {
# }
#             ).addTo(map_6b15645fe5cd772e8680505acc0e757f);
#
#
#             var icon_a2ba35c7837706fe6ccfcda3060fe70f = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;cutlery&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_fbfe499b7bb606233520a13cf5368638.setIcon(icon_a2ba35c7837706fe6ccfcda3060fe70f);
#
#
#         var popup_799c593e78ad382c90eb26360ed0b584 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_f010bc38f80de3a8fa2c55603aa487c8 = $(`&lt;div id=&quot;html_f010bc38f80de3a8fa2c55603aa487c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;b&gt;Le Comptoir de la Gastronomie&lt;/b&gt;&lt;br&gt;         34 rue Montmartre&lt;br&gt;         &lt;a href=&quot;https://www.yelp.com/biz/le-comptoir-de-la-gastronomie-paris?adjust_creative=NnnrNySybEItfMzq-c4qFw&amp;utm_campaign=yelp_api_v3&amp;utm_medium=api_v3_business_search&amp;utm_source=NnnrNySybEItfMzq-c4qFw&quot; target=&quot;_blank&quot;&gt;Lien vers Yelp&lt;/a&gt;         &lt;/div&gt;`)[0];
#                 popup_799c593e78ad382c90eb26360ed0b584.setContent(html_f010bc38f80de3a8fa2c55603aa487c8);
#
#
#
#         marker_fbfe499b7bb606233520a13cf5368638.bindPopup(popup_799c593e78ad382c90eb26360ed0b584)
#         ;
#
#
#
#
#             var marker_6d92fc00674880ba9d9ddbfc15eecc31 = L.marker(
#                 [48.854754, 2.342119],
#                 {
# }
#             ).addTo(map_6b15645fe5cd772e8680505acc0e757f);
#
#
#             var icon_d52ea9a5d52cfe887c6c78c709cca2fb = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;cutlery&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_6d92fc00674880ba9d9ddbfc15eecc31.setIcon(icon_d52ea9a5d52cfe887c6c78c709cca2fb);
#
#
#         var popup_96431725d1447a4a434c5a34eec55211 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_efaf7b881ca9e0774988b74a5a5a72b9 = $(`&lt;div id=&quot;html_efaf7b881ca9e0774988b74a5a5a72b9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;b&gt;Bistro des Augustins&lt;/b&gt;&lt;br&gt;         39 quai des Grands Augustins&lt;br&gt;         &lt;a href=&quot;https://www.yelp.com/biz/bistro-des-augustins-paris?adjust_creative=NnnrNySybEItfMzq-c4qFw&amp;utm_campaign=yelp_api_v3&amp;utm_medium=api_v3_business_search&amp;utm_source=NnnrNySybEItfMzq-c4qFw&quot; target=&quot;_blank&quot;&gt;Lien vers Yelp&lt;/a&gt;         &lt;/div&gt;`)[0];
#                 popup_96431725d1447a4a434c5a34eec55211.setContent(html_efaf7b881ca9e0774988b74a5a5a72b9);
#
#
#
#         marker_6d92fc00674880ba9d9ddbfc15eecc31.bindPopup(popup_96431725d1447a4a434c5a34eec55211)
#         ;
#
#
#
#
#             var marker_a3a5d9749f46346bd0655623d20e9337 = L.marker(
#                 [48.85755, 2.34938],
#                 {
# }
#             ).addTo(map_6b15645fe5cd772e8680505acc0e757f);
#
#
#             var icon_7857f1a7cdfbc2c652acd27f38244228 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;cutlery&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_a3a5d9749f46346bd0655623d20e9337.setIcon(icon_7857f1a7cdfbc2c652acd27f38244228);
#
#
#         var popup_162f107af54164ef28a96e5ced4666b4 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_7a22666e04a3a3fe8ccc6eb051d01b27 = $(`&lt;div id=&quot
