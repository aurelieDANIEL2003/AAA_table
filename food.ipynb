# %%
import json
import requests
import pandas as pd

#Clé API
API_KEY = "m2Q6PLrDbFonmYwJT-IqBq6DmYX_MhZ_DV6Gnls4JTnj0qUtuNKnaEt48q0lr9mrZM-husmMgztJc4TKF9TbChpv7nfCKU5GYKH7AxT3rtWwSJBVBtR8RfZmihaSZ3Yx"

#URL de base
url = "https://api.yelp.com/v3/businesses/search"

#Paramètres de la requête
params = {
    "location": "France",  # Exemple : ville
    "term": "restaurants",       # Exemple : type d'entreprise
    "limit": 50,                 # Nombre de résultats
    "offset": 0,                 # Pagination
    "sort_by": "best_match",     # Critères de tri
}

#En-têtes HTTP
headers = {
    "Authorization": f"Bearer {API_KEY}",  # Clé API
    "Accept": "application/json"          # Format attendu
}

#Envoi de la requête GET
response = requests.get(url, headers=headers, params=params)

# #Vérification du statut de la requête

data = response.json()  # Extraction des données JSON
data         # Affiche les résultats
# Out:
# {'businesses': [{'id': 'IU9_wVOGBKjfqTTpAXpKcQ',
#    'alias': 'bistro-des-augustins-paris',
#    'name': 'Bistro des Augustins',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ctHDHMiqeUGs8Zcj71nk7g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bistro-des-augustins-paris?adjust_creative=6yklRAIx-GJ0_gwgV7nzJQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6yklRAIx-GJ0_gwgV7nzJQ',
#    'review_count': 531,
#    'categories': [{'alias': 'bistros', 'title': 'Bistros'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.4,
#    'coordinates': {'latitude': 48.854754, 'longitude': 2.342119},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': '39 quai des Grands Augustins',
#     'address2': None,
#     'address3': None,
#     'city': 'Paris',
#     'zip_code': '75006',
#     'country': 'FR',
#     'state': '75',
#     'display_address': ['39 quai des Grands Augustins',
# ...

# %%
import json
import requests
import pandas as pd

#Clé API
API_KEY = "FnAs6986-medBbzafaCtjB4dG-FAFNulPGg9wH5EJFdp6XjEoY4Bvq8pqYfY4x_HmtezfrONesvmvlRkf9NFRumxA4vhTiPyAw9GS5JtMEA1xKlJ_W70uydnXgeSZ3Yx"

#URL de base
url = "https://api.yelp.com/v3/businesses/search"

#Paramètres de la requête
params = {
    "location": "France",  # Exemple : ville
    "term": "restaurants",       # Exemple : type d'entreprise
    "limit": 50,                 # Nombre de résultats
    "offset": 0,                 # Pagination
    "sort_by": "best_match",     # Critères de tri
}

#En-têtes HTTP
headers = {
    "Authorization": f"Bearer {API_KEY}",  # Clé API
    "Accept": "application/json"          # Format attendu
}
#Envoi de la requête GET
r = requests.get(url, headers=headers, params=params)

#Vérification du statut de la requête

#data = response.json()  # Extraction des données JSON
       # Affiche les résultats
data = json.loads(r.text)
df = pd.json_normalize(data)
data.keys()
df = pd.json_normalize(r.json(), record_path="businesses")
df.head()
# Out:
#                        id                          alias  \
# 0  IU9_wVOGBKjfqTTpAXpKcQ     bistro-des-augustins-paris
# 1  BuJnfWI86tTxFUon071EKg      brasserie-bellanger-paris
# 2  TWsuxL7J0iACK5KplxZMtA        le-p-tit-bistro-paris-2
# 3  BPqBRgweCDLInSRww9qmYg  le-corner-saint-germain-paris
# 4  cEjF41ZQB8-SST8cd3EsEw       l-avant-comptoir-paris-3
#
#                       name                                          image_url  \
# 0     Bistro des Augustins  https://s3-media2.fl.yelpcdn.com/bphoto/ctHDHM...
# 1      Brasserie Bellanger  https://s3-media3.fl.yelpcdn.com/bphoto/TO1OgG...
# 2          Le P'tit Bistro  https://s3-media4.fl.yelpcdn.com/bphoto/lrnzcs...
# 3  Le Corner Saint Germain  https://s3-media4.fl.yelpcdn.com/bphoto/1WgV5b...
# 4         L'Avant Comptoir  https://s3-media2.fl.yelpcdn.com/bphoto/V38oU4...
#
#    is_closed                                                url  review_count  \
# ...

# %%
df.columns
# Out:
# Index(['id', 'alias', 'name', 'image_url', 'is_closed', 'url', 'review_count',
#        'categories', 'rating', 'transactions', 'price', 'phone',
#        'display_phone', 'distance', 'business_hours', 'coordinates.latitude',
#        'coordinates.longitude', 'location.address1', 'location.address2',
#        'location.address3', 'location.city', 'location.zip_code',
#        'location.country', 'location.state', 'location.display_address',
#        'attributes.business_temp_closed', 'attributes.menu_url',
#        'attributes.open24_hours', 'attributes.waitlist_reservation'],
#       dtype='object')

# %%
test = df['categories'].iloc[0]
test[0]['title']
# Out:
# 'Bistros'

# %%
data.keys()
df = pd.json_normalize(r.json(), record_path="businesses")
df.head()
# Out:
#                        id                                alias  \
# 0  -0iLH7iQNYtoURciDpJf6w  le-comptoir-de-la-gastronomie-paris
# 1  IU9_wVOGBKjfqTTpAXpKcQ           bistro-des-augustins-paris
# 2  TWsuxL7J0iACK5KplxZMtA              le-p-tit-bistro-paris-2
# 3  BuJnfWI86tTxFUon071EKg            brasserie-bellanger-paris
# 4  BPqBRgweCDLInSRww9qmYg        le-corner-saint-germain-paris
#
#                             name  \
# 0  Le Comptoir de la Gastronomie
# 1           Bistro des Augustins
# 2                Le P'tit Bistro
# 3            Brasserie Bellanger
# 4        Le Corner Saint Germain
#
#                                            image_url  is_closed  \
# 0  https://s3-media4.fl.yelpcdn.com/bphoto/nNraWW...      False
# 1  https://s3-media2.fl.yelpcdn.com/bphoto/ctHDHM...      False
# 2  https://s3-media4.fl.yelpcdn.com/bphoto/lrnzcs...      False
# 3  https://s3-media3.fl.yelpcdn.com/bphoto/TO1OgG...      False
# ...

# %%
# essai boucle ne pas lancer tant que pas sure
# API limitée a 1000

# %%
import json
import requests
import pandas as pd

NBoffset = 0

for i in range (2):

    #Clé API
    API_KEY = "m2Q6PLrDbFonmYwJT-IqBq6DmYX_MhZ_DV6Gnls4JTnj0qUtuNKnaEt48q0lr9mrZM-husmMgztJc4TKF9TbChpv7nfCKU5GYKH7AxT3rtWwSJBVBtR8RfZmihaSZ3Yx"

    #URL de base
    url = "https://api.yelp.com/v3/businesses/search"

    #Paramètres de la requête
    params = {
        "location": "France",  # Exemple : ville
        "term": "restaurants",       # Exemple : type d'entreprise
        "limit": 50,                 # Nombre de résultats
        "offset": NBoffset,                 # Pagination
        "sort_by": "best_match",     # Critères de tri
    }

    #En-têtes HTTP
    headers = {
        "Authorization": f"Bearer {API_KEY}",  # Clé API
        "Accept": "application/json"          # Format attendu
    }

    r = requests.get(url, headers=headers, params=params)

#Vérification du statut de la requête

       # Affiche les résultats
    data = json.loads(r.text)
    df = pd.json_normalize(data)
    data.keys()
    df = pd.json_normalize(r.json(), record_path="businesses")
    df
    NBoffset+=50

# %%
response = requests.get(url, headers=headers, params=params)
data = response.json()
data['businesses'][0].keys()
allarticles = []

for  in range(4):  #Mle nombre d'appels à l'API au maximum
    #Le nombre mis dans le range donnera le nombre de centaines d'articles
    #(mais aussi le nombre d'appels à l'API)
    response = requests.get(url,headers=headers, params=params)
    data = response.json()
    all_articles.extend(data['businesses'])
    params["offset"] += 50

#Création du dataframe
df = pd.DataFrame(all_articles)
df = df[['id', 'alias', 'name', 'image_url', 'is_closed', 'url', 'review_count', 'categories', 'rating', 'coordinates', 'transactions', 'price', 'location', 'phone', 'display_phone', 'distance', 'business_hours', 'attributes']]

#Affichage de 3 lignes aléatoires
df.sample(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 29 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   id                               50 non-null     object
#  1   alias                            50 non-null     object
#  2   name                             50 non-null     object
#  3   image_url                        50 non-null     object
#  4   is_closed                        50 non-null     bool
#  5   url                              50 non-null     object
#  6   review_count                     50 non-null     int64
#  7   categories                       50 non-null     object
#  8   rating                           50 non-null     float64
#  9   transactions                     50 non-null     object
#  10  price                            43 non-null     object
#  11  phone                            50 non-null     object
# ...
